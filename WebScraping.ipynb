# %% [markdown]
# Web Scraping is done aautomatically using python scripts using requests+beautiful soup
# While doing so read the terms and conditions and the rate limit to prevent the API bannings, always add a delay
#
# Web Scraping is always done based on the HTML elements used in the web page
# so learn a little HTML
